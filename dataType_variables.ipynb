# %%
2+3+9
print('---')
20/3
# Out:
# ---
# ---
# 6.666666666666667

# %%
# number of variables-
cost= 1.25
profit=2
bags=10

x=bags*(cost+profit)
x
# Out:
# 32.5

# %%
# operators

x=10
y=30
# to see output comment other expression
# x==y
# x>y
  x<y
# Out:
# True

# %%
my_color = "blue"

my_color
# Out:
# 'blue'

# %%
color1, color2, color3 = "red", "green", "blue"

# %%
print("color1 :",color1,"color2 :",color2,"color3 :",color3)
# Out:
# color1 : red color2 : green color3 : blue

# %% [markdown]
# ### Built-in data types in Python
#
#    * Integer : there's just one int type (as opposed to short, int, long, long long, unsigned int, etc. in C/C++/Java)
#    * Float
#    * Boolean
#    * None
#    * String
#    * List
#    * Tuple
#    * Dictionary

# %% [markdown]
# ![6cg2E9Q.png](attachment:6cg2E9Q.png)

# %%
a_variable = 23
is_today_Saturday = False
my_favorite_car = "Delorean"
the_3_musketeers = ["Athos", "Porthos", "Aramis"]

# %%
type(a_variable)
# Out:
# int

# %%
type(is_today_Saturday)
# Out:
# bool

# %%
type(my_favorite_car)
# Out:
# str

# %%
type(the_3_musketeers)
# Out:
# list

# %%
pi = 3.1415926
type(pi)
# 3.0 , 4. , 0.01 , 1e-2 , 6.02214076e23  :- all are float
# Out:
# float

# %% [markdown]
# Booleans are automatically converted to ints when used in arithmetic operations. True is converted to 1 and False is converted to 0.

# %%
10 + True
# Out:
# 11

# %%
10 + False
# Out:
# 10

# %%
bool(True), bool(1), bool(2.0), bool("hello"), bool([1,2]), bool((2,3)), bool(range(10)), bool(range(0))
# Out:
# (True, True, True, True, True, True, True, False)

# %% [markdown]
# None
#
# The None type includes a single value None, used to indicate the absence of a value. None has the type NoneType. It is often used to declare a variable whose value may be assigned later.

# %%
nothing = None

type(nothing)
# Out:
# NoneType

# %% [markdown]
# String
#
# Strings must be surrounded using quotations (either the single quote ' or the double quote ").

# %%
name = "sahil-sharma"
name , type(name)
# Out:
# ('sahil-sharma', str)

# %%
a_music_pun = """
Two windmills are standing in a field and one asks the other, 
"What kind of music do you like?"  

The other says, 
"I'm a big metal fan."
"""

print(a_music_pun)
# Out:
# Two windmills are standing in a field and one asks the other,
# "What kind of music do you like?"
#
# The other says,
# "I'm a big metal fan."

# %%
# check the length of the a string... len()

len(a_music_pun)
# Out:
# 141

# %%
# Note that special characters like \n and escaped characters like \" count as a single character, even though they are written and sometimes printed as two characters.
multiline_string = """abc
d"""
multiline_string, len(multiline_string)
# Out:
# ('abc\nd', 5)

# %%
list(multiline_string)
# Out:
# ['a', 'b', 'c', '\n', 'd']

# %% [markdown]
# Strings also support several list operations, which are discussed in the next section. We'll look at a couple of examples here.
#
# You can access individual characters within a string using the [] indexing notation. Note the character indices go from 0 to n-1, where n is the length of the string.

# %%
today = "Saturday"

# %%
print("today[0] :",today[0],"  today[3] :",today[3],"  today[5:8]",today[5:8])
# Out:
# today[0] : S   today[3] : u   today[5:8] day

# %% [markdown]
# You can also check whether a string contains a some text using the in operator.

# %%
'day' in today  , 'Sun' in today
# Out:
# (True, False)

# %%
# Two or more strings can be joined or concatenated using the + operator
full_name = "Sahil Sharma"
greeting = "Hello"
greeting + full_name ,  greeting + " " + full_name
# Out:
# ('HelloSahil Sharma', 'Hello Sahil Sharma')

# %% [markdown]
# The .lower(), .upper() and .capitalize() methods are used to change the case of the characters.
#
# -> today.lower()
#
#     'saturday'
#
# -> "saturday".upper()
#
#     'SATURDAY'
#
# ->  "monday".capitalize() # changes first character to     uppercase
#
#     'Monday'

# %%
# today = "Saturday"
another_day = today.replace("Satur","Wednes")
another_day 
# 'replace' returns a new string, and the original string is not modified.
# Out:
# 'Wednesday'

# %% [markdown]
# The `.split` method splits a string into a list of strings at every occurrence of provided character(s).

# %%
"Sun,Mon,Tue,Wed,Thu,Fri,Sat".split(",")
# Out:
# ['Sun', 'Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat']

# %% [markdown]
# The `.strip` method removes whitespace characters from the beginning and end of a string.

# %%
a_long_line = "       This is a long line with some space before, after,     and some space in the middle..    "

line_strippeed = a_long_line.strip()
line_strippeed
# Out:
# 'This is a long line with some space before, after,     and some space in the middle..'

# %% [markdown]
# The .format method combines values of other data types, e.g., integers, floats, booleans, lists, etc. with strings. You can use format to construct output messages for display.

# %%
# Input variables
cost_of_ice_bag = 1.25
profit_margin = .2
number_of_bags = 500

# Template for output message
output_template = """If a grocery store sells ice bags at $ {} per bag, with a profit margin of {} %, 
then the total profit it makes by selling {} ice bags is $ {}."""

print(output_template)
# Out:
# If a grocery store sells ice bags at $ {} per bag, with a profit margin of {} %,
# then the total profit it makes by selling {} ice bags is $ {}.

# %%
# Inserting values into the string
total_profit = cost_of_ice_bag * profit_margin * number_of_bags
output_message = output_template.format(cost_of_ice_bag, profit_margin*100, number_of_bags, total_profit)

print(output_message)
# Out:
# If a grocery store sells ice bags at $ 1.25 per bag, with a profit margin of 20.0 %,
# then the total profit it makes by selling 500 ice bags is $ 125.0.

# %%
# here we have use '+' operator insted of .format() method
"If a grocery store sells ice bags at $ " + str(cost_of_ice_bag) + ", with a profit margin of " + str(profit_margin)
# Out:
# 'If a grocery store sells ice bags at $ 1.25, with a profit margin of 0.2'

# %% [markdown]
# ### List
#
# A list in Python is an ordered collection of values. Lists can hold values of different data types and support operations to add, remove, and change values. Lists have the type `list`.
#
# To create a list, enclose a sequence of values within square brackets `[` and `]`, separated by commas.
#
# * You can access an element from the list using its index, e.g., `fruits[2]`  returns the element at index 2 within the list `fruits` . The starting index of a list is 0.
#
# * You can use negative indices to access elements from the end of a list, e.g., `fruits[-1]` returns the last element, `fruits[-2]` returns the second last element, and so on.

# %%
fruits = ['apple', 'banana', 'cherry'] # list 1 of similar DT

a_list = [23, 'hello', None, 3.14, fruits, 3 <= 5] # list 2 of different DT

print("length of fruits :",len(fruits)," length of a_list :",len(a_list))
# Out:
# length of fruits : 3  length of a_list : 6

# %%
a_list
# Out:
# [23, 'hello', None, 3.14, ['apple', 'banana', 'cherry'], True]

# %%
empty_list = []  # empty list 
empty_list, len(empty_list)
# Out:
# ([], 0)

# %%
# access the element of the list....
fruits[0], fruits[2], a_list[1], a_list[4], a_list[4][1]
# Out:
# ('apple', 'cherry', 'hello', ['apple', 'banana', 'cherry'], 'banana')

# %% [markdown]
# You can also change the value at a specific index within a list using the assignment operation.

# %%
fruits # ['apple', 'banana', 'cherry']
fruits[1] = 'blueberry'
fruits
# Out:
# ['apple', 'blueberry', 'cherry']

# %%
# add new value to the list
fruits.append('dates') 
fruits
# Out:
# ['apple', 'blueberry', 'cherry', 'dates']

# %%
# inserted at a specific index using the insert method.
fruits.insert(1,'banana')
fruits
# Out:
# ['apple', 'banana', 'blueberry', 'cherry', 'dates']

# %%
# remove a value from a list using the remove method.
fruits.remove("blueberry")
fruits
# Out:
# ['apple', 'banana', 'cherry', 'dates']

# %%
# remove an element from a specific index, use the pop method
fruits.pop(1) 
fruits
# Out:
# ['apple', 'cherry', 'dates']

# %%
# If no index is provided, the `pop` method removes the last element of the list.
fruits.pop()
fruits
# Out:
# ['apple', 'cherry']

# %%
# You can test whether a list contains a value using the in operator.
'pineapple' in fruits  , 'cherry' in fruits
# Out:
# (False, True)

# %% [markdown]
# ### Tuple
#
# A tuple is an ordered collection of values, similar to a list. However, it is not possible to add, remove, or modify values in a tuple. A tuple is created by enclosing values within parentheses `(` and `)`, separated by commas.
#
# > Any data structure that cannot be modified after creation is called *immutable*. You can think of tuples as immutable lists.

# %%
fruits = ('apple', 'cherry', 'dates')
fruits
# Out:
# ('apple', 'cherry', 'dates')

# %%
len(fruits), fruits[1], fruits[-1]
# Out:
# (3, 'cherry', 'dates')

# %%
# try to change an element
fruits[0] = 'avocado'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\sahilsharma\Desktop\pdf\python code\practice👀\dataType_variables.ipynb Cell 59 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/sahilsharma/Desktop/pdf/python%20code/practice%F0%9F%91%80/dataType_variables.ipynb#Y114sZmlsZQ%3D%3D?line=0'>1</a> # try to change an element
# ----> <a href='vscode-notebook-cell:/c%3A/Users/sahilsharma/Desktop/pdf/python%20code/practice%F0%9F%91%80/dataType_variables.ipynb#Y114sZmlsZQ%3D%3D?line=1'>2</a> fruits[0] = 'avocado'
#
# TypeError: 'tuple' object does not support item assignment

# %%
# try to append an element
fruits.append('blueberry')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\sahilsharma\Desktop\pdf\python code\practice👀\dataType_variables.ipynb Cell 60 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/sahilsharma/Desktop/pdf/python%20code/practice%F0%9F%91%80/dataType_variables.ipynb#Y121sZmlsZQ%3D%3D?line=0'>1</a> # try to append an element
# ----> <a href='vscode-notebook-cell:/c%3A/Users/sahilsharma/Desktop/pdf/python%20code/practice%F0%9F%91%80/dataType_variables.ipynb#Y121sZmlsZQ%3D%3D?line=1'>2</a> fruits.append('blueberry')
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
# try to remove an element
fruits.remove('apple')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\sahilsharma\Desktop\pdf\python code\practice👀\dataType_variables.ipynb Cell 61 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/sahilsharma/Desktop/pdf/python%20code/practice%F0%9F%91%80/dataType_variables.ipynb#Y123sZmlsZQ%3D%3D?line=0'>1</a> # try to remove an element
# ----> <a href='vscode-notebook-cell:/c%3A/Users/sahilsharma/Desktop/pdf/python%20code/practice%F0%9F%91%80/dataType_variables.ipynb#Y123sZmlsZQ%3D%3D?line=1'>2</a> fruits.remove('apple')
#
# AttributeError: 'tuple' object has no attribute 'remove'

# %% [markdown]
# You can also create a tuple with just one element by typing a comma after it. Just wrapping it with parentheses ( and ) won't make it a tuple.
#
# * single_element_tuple = 4,
#
# single_element_tuple
#
# (4,)
#
# * another_single_element_tuple = (4,)
#
# another_single_element_tuple
#
# (4,)
#
# * not_a_tuple = (4)
#
# not_a_tuple
#
# 4
#
# Tuples are often used to create multiple variables with a single statement.
#
# * point = (3, 4)
#
# point_x, point_y = point
#
# point_x
#
# 3
#
# point_y
#
# 4

# %%
# convert list into tuple and tuple to list.......
## You can convert a list into a tuple using the `tuple` function, and vice versa using the `list` function
tuple(['one', 'two', 'three'])  # output : ('one', 'two', 'three')
list(('Athos', 'Porthos', 'Aramis')) # output : ['Athos', 'Porthos', 'Aramis']
# Out:
# ['Athos', 'Porthos', 'Aramis']

# %% [markdown]
# ### Dictionary
#
# A dictionary is an unordered collection of items. Each item stored in a dictionary has a `key`  and `value` . You can use a key to retrieve the corresponding value from the dictionary.  Dictionaries have the type `dict`.
#
# Dictionaries are often used to store many pieces of information e.g. details about a person, in a single variable. Dictionaries are created by enclosing key-value pairs within braces or curly brackets `{` and `}`.

# %%
person1 = {
    'name': 'John Doe',
    'sex': 'Male',
    'age': 32,
    'married': True
}

person1
# Out:
# {'name': 'John Doe', 'sex': 'Male', 'age': 32, 'married': True}

# %%
# Dictionaries can also be created using the dict function.
person2 = dict(name='Jane Judy', sex='Female', age=28, married=False)
person2
# Out:
# {'name': 'Jane Judy', 'sex': 'Female', 'age': 28, 'married': False}

# %%
# Keys can be used to access values using square brackets [ and ].
person1['name'] , person1['married']
# Out:
# ('John Doe', True)

# %%
# assignment operator can also be used to add new key-value pairs to the dictionary
person1['address'] = '1, Penny Lane'

person1
# Out:
# {'name': 'John Doe',
#  'sex': 'Male',
#  'age': 32,
#  'married': True,
#  'address': '1, Penny Lane'}

# %%
# remove a key and value
person1.pop('address')
# Out:
# '1, Penny Lane'

# %%
# to view the list of keys, values, or key-value pairs inside it.

print(person1.keys())
print(person1.values())
print(person1.items())
# Out:
# dict_keys(['name', 'sex', 'age', 'married'])
# dict_values(['John Doe', 'Male', 32, True])
# dict_items([('name', 'John Doe'), ('sex', 'Male'), ('age', 32), ('married', True)])
